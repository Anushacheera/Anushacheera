# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushacheera/Anushacheera/blob/main/disease_detector_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Load Dataset
df = pd.read_excel("/content/heart_disease.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1277/3854791282.py in <cell line: 0>()
#       1 #Load Dataset
# ----> 2 df = pd.read_excel("/content/heart_disease.xlsx")
#       3 df
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df.head(5)

# %%
xls = pd.ExcelFile("/content/heart_disease.xlsx")

print(xls.sheet_names) #so here two sheets are there

# %%
#So do not use the Description sheet for model building. Use: sheet_name="Heart_disease"

# %%
df.isnull().sum().sum()

# %%
df.duplicated().sum().sum()

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/3771845804.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Load the actual dataset
df = pd.read_excel(
    "/content/heart_disease.xlsx",
    sheet_name="Heart_disease"
)

df

# %%
df.head(5)

# %%
df.info()

# %%
df.isnull().sum().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/3061644919.py in <cell line: 0>()
# ----> 1 df.isnull().sum().sum()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum().sum()/df.size

# %%
#In Percentage
0.005252456794307014 * 100 #o/p:0.5 %
# Out:
# 0.5252456794307014

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/857714779.py in <cell line: 0>()
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.describe()

# %%
df.describe(include='object')

# %%
df.isnull().sum().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/3061644919.py in <cell line: 0>()
# ----> 1 df.isnull().sum().sum()
#
# NameError: name 'df' is not defined

# %%
#Replacing the Missing Values

# %%
numerical_columns = df.select_dtypes(
    include=['int64', 'float64']
).columns

categorical_columns = df.select_dtypes(
    include=['object']
).columns

print("Numerical Columns:")
print(numerical_columns)

print("\nCategorical Columns:")
print(categorical_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/455093602.py in <cell line: 0>()
# ----> 1 numerical_columns = df.select_dtypes(
#       2     include=['int64', 'float64']
#       3 ).columns
#       4
#       5 categorical_columns = df.select_dtypes(
#
# NameError: name 'df' is not defined

# %%
for col in numerical_columns:
    df[col] = df[col].fillna(df[col].median())

# %%
for col in categorical_columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
print("Total Missing Values:", df.isnull().sum().sum())

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/655507945.py in <cell line: 0>()
# ----> 1 print("Duplicate Rows:", df.duplicated().sum())
#
# NameError: name 'df' is not defined

# %%
df = df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/3528702638.py in <cell line: 0>()
# ----> 1 df = df.drop_duplicates()
#
# NameError: name 'df' is not defined

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/655507945.py in <cell line: 0>()
# ----> 1 print("Duplicate Rows:", df.duplicated().sum())
#
# NameError: name 'df' is not defined

# %%
#Check Target Variable
#According to your description sheet, num is your target column.
df['num'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/2043642926.py in <cell line: 0>()
#       1 #Check Target Variable
#       2 #According to your description sheet, num is your target column.
# ----> 3 df['num'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#Box Plot - Checking Outliers
for each_col in df.select_dtypes(exclude = 'object').columns:
  sns.boxplot(y = df[each_col])
  plt.title(f"Boxplot of Column Name :{each_col}")
  plt.show()

# %%
#Box Plot - Checking Outliers
numerical_columns = df.select_dtypes(include='number').columns

for each_col in numerical_columns:

    q1 = df[each_col].quantile(0.25)
    q3 = df[each_col].quantile(0.75)

    IQR = q3 - q1

    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR

    df.loc[:, each_col] = df[each_col].clip(
        lower_bound,
        upper_bound
    )

# %%
#Box Plot - Checking Outliers
for each_col in df.select_dtypes(exclude = 'object').columns:
  sns.boxplot(y = df[each_col])
  plt.title(f"Boxplot of Column Name :{each_col}")
  plt.show()

# %%
#If you want a binary classification:

#0 → No Heart Disease
#1, 2, 3, 4 → Heart Disease

# %%
#Creating binary Target Column
df['target'] = (df['num'] > 0).astype(int)

df['target'].value_counts()

# %%
#Split X and y values
X = df.drop(columns=['num', 'target'])
y = df['target']

# %%
#Features
print(X.columns)

# %%
print(numerical_columns)

# %%
#Visualize Feature Distributions - Histogram
numerical_columns = X.select_dtypes(
    include=['int64', 'float64']
).columns

X[numerical_columns].hist(
    figsize=(15, 12),
    bins=20,
    edgecolor='black'
)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/3178045035.py in <cell line: 0>()
#       1 #Visualize Feature Distributions - Histogram
# ----> 2 numerical_columns = X.select_dtypes(
#       3     include=['int64', 'float64']
#       4 ).columns
#       5
#
# NameError: name 'X' is not defined

# %%
#Correlation Heatmap
plt.figure(figsize = (8,4))
sns.heatmap(
    df.corr(numeric_only=True),
    annot = True,
    fmt = ".2f",
    cmap = "coolwarm"



)
plt.title("HeatMap of Heart Disease : ")
plt.xticks(rotation = 45)
plt.show()

# %%
df.info()

# %%
#Checking Categorical Columns in X(features)
X.select_dtypes(include='object').columns

# %%
#handling Categorical columns
#using One Hot Encoding for categorical Columns
X = pd.get_dummies(X, drop_first=True, dtype=int)

# %%
df.head(5)

# %%
X = df.drop(columns=['num', 'target'])
y = df['target']

# %%
#Apply One Hot Encoding for Numerical Columns:
X = pd.get_dummies(
    X,
    drop_first=True,
    dtype=int
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/422686478.py in <cell line: 0>()
#       1 #Apply One Hot Encoding for Numerical Columns:
#       2 X = pd.get_dummies(
# ----> 3     X,
#       4     drop_first=True,
#       5     dtype=int
#
# NameError: name 'X' is not defined

# %%
X.head(5)

# %%
X.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/3566440994.py in <cell line: 0>()
# ----> 1 X.dtypes
#
# NameError: name 'X' is not defined

# %%
#Train Test Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/3358660842.py in <cell line: 0>()
# ----> 1 print("X_train shape:", X_train.shape)
#       2 print("X_test shape:", X_test.shape)
#       3
#       4 print("y_train shape:", y_train.shape)
#       5 print("y_test shape:", y_test.shape)
#
# NameError: name 'X_train' is not defined

# %%
#Build and Train Decision Tree
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(
    criterion="gini",
    max_depth=4,
    random_state=42
)

dt_model.fit(X_train, y_train)

#Make Predictions:
y_pred = dt_model.predict(X_test)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

plot_tree(
    dt_model,
    filled=True,
    rounded=True,
    fontsize=8,
    feature_names=X.columns,
    class_names=['0', '1'] #display target Output
)

# Save as PDF
plt.savefig("decision_tree.pdf", bbox_inches="tight")

# Save as PNG
plt.savefig("decision_tree.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
#To check First Few Predictions:
comparison = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': y_pred
})

comparison.head(10)

# %%
#Evaluation of Decision tree
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)

# %%
#Precision , Recall , F1 Scoore
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1277/1520705492.py in <cell line: 0>()
#       2 from sklearn.metrics import classification_report
#       3
# ----> 4 print(classification_report(y_test, y_pred))
#
# NameError: name 'y_test' is not defined

# %%
#Confusion Matrix:
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)

# %%
#Confusion Matrix Visualization:
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=['No Disease', 'Disease'],
    yticklabels=['No Disease', 'Disease']
)

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Decision Tree')

plt.show()

# %%
#ROC AUC Curve
from sklearn.metrics import roc_auc_score

y_prob = dt_model.predict_proba(X_test)[:, 1]

roc_auc = roc_auc_score(y_test, y_prob)

print("ROC-AUC Score:", roc_auc)

# %%
#ROC Curve  Visulaization
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(
    y_test,
    y_prob
)

plt.figure(figsize=(7, 5))

plt.plot(
    fpr,
    tpr,
    label=f"ROC Curve (AUC = {roc_auc:.2f})"
)

plt.plot([0, 1], [0, 1], linestyle='--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Decision Tree")

plt.legend()

plt.show()

# %%
#Check Feature Importance:
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': dt_model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

feature_importance

# %%
#Visulaize feature Importance:
plt.figure(figsize=(10, 6))

plt.barh(
    feature_importance['Feature'],
    feature_importance['Importance']
)

plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Feature Importance - Decision Tree')

plt.gca().invert_yaxis()

plt.show()

# %%
#Hyper Parameter Tuning:
#1. Using GridSearchCV with some arguments
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Define the Decision Tree model
dt = DecisionTreeClassifier(random_state=42)

# Define hyperparameters
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 7, 10, None],
    'min_samples_split': [2, 5, 10]
}

# Grid Search
grid_search = GridSearchCV(
    estimator=dt,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Train with different combinations
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters:")
print(grid_search.best_params_)

# Best cross-validation accuracy
print("\nBest CV Accuracy:")
print(grid_search.best_score_)

# %%
#Get the best Decision Tree Model
best_dt_model = grid_search.best_estimator_

print(best_dt_model)

# %%
#Pediction using Tuned Model:
y_pred_tuned = best_dt_model.predict(X_test)

# %%
#Evaluate the Tunde Model:
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

# Accuracy
tuned_accuracy = accuracy_score(
    y_test,
    y_pred_tuned
)

print("Tuned Model Accuracy:", tuned_accuracy)

# Classification Report
print("\nClassification Report:")
print(classification_report(
    y_test,
    y_pred_tuned
))

# %%
#Comparing Normal DT Model Vs Tuned Model:
comparison = pd.DataFrame({
    'Model': [' Decision Tree', 'Tuned Decision Tree'],
    'Accuracy': [
        accuracy_score(y_test, y_pred),
        accuracy_score(y_test, y_pred_tuned)
    ],
    'ROC-AUC': [
        roc_auc_score(y_test, y_prob),
        roc_auc_score(y_test, y_prob_tuned)
    ]
})

comparison

# %%
"""
The performance of the default Decision Tree model was compared with the hyperparameter-tuned Decision Tree model.
The default model achieved an accuracy of 70.33% and a ROC-AUC score of 0.6989.
 After applying GridSearchCV to optimize hyperparameters such as criterion, maximum depth, and minimum samples split,
 the tuned Decision Tree achieved an improved accuracy of 73.63% and ROC-AUC score of 0.7815."""
